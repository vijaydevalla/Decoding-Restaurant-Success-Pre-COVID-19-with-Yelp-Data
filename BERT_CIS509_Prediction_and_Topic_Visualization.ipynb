# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Install Transformers library
# !pip install transformers
# Out:
# Mounted at /content/drive
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.37.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CIS509/Restaurants_Data_2018.csv')

# Drop unnecessary columns
df = df[['text', 'name', 'is_open']]

# Group reviews by restaurant name
grouped_reviews = df.groupby('name')['text'].apply(lambda x: ' '.join(x)).reset_index()

# Merge with is_open column
grouped_data = grouped_reviews.merge(df[['name', 'is_open']], on='name').drop_duplicates()

# Convert is_open to binary labels
grouped_data['is_open'] = grouped_data['is_open'].astype(int)

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into train and test sets
train_texts, test_texts, train_labels, test_labels = train_test_split(grouped_data['text'],
                                                                      grouped_data['is_open'],
                                                                      test_size=0.2,
                                                                      random_state=42)

# %%
from transformers import BertTokenizer

# Load BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Tokenize text data
train_encodings = tokenizer(train_texts.tolist(), truncation=True, padding=True)
test_encodings = tokenizer(test_texts.tolist(), truncation=True, padding=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
import tensorflow as tf

# Convert labels to TensorFlow dataset
train_dataset = tf.data.Dataset.from_tensor_slices((dict(train_encodings), train_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((dict(test_encodings), test_labels))

# %%
# !pip install bertopic

import locale
locale.getpreferredencoding = lambda: "UTF-8"

from bertopic import BERTopic
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.10/dist-packages (0.16.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.25.2)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.8.33)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.5.5)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.4.0)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.37)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.37.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.9.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)

# %%
from transformers import TFBertForSequenceClassification
learning_rates = [ 0.00002, 0.000002]
accuracies = []

for lr in learning_rates:
    # Fine-tune BERT model
    model = TFBertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

    # Using Adam optimizer with specified learning rate
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

    # Using sparse categorical cross-entropy loss function
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)  # Sparse categorical cross-entropy loss function

    metrics = ['accuracy']
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    # Fine-tune the model on the downstream task
    history = model.fit(train_dataset.shuffle(1000).batch(8), epochs=3, batch_size=8, verbose=0)

    # Evaluate the model
    test_loss, test_accuracy = model.evaluate(test_dataset.batch(16), verbose=0)
    accuracies.append(test_accuracy)

# Print accuracies for each learning rate
for lr, acc in zip(learning_rates, accuracies):
    print(f'Learning Rate: {lr}, Test Accuracy: {acc}')
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Learning Rate: 2e-05, Test Accuracy: 0.7401574850082397
# Learning Rate: 2e-06, Test Accuracy: 0.7401574850082397

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_dataset.batch(8), verbose=2)
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 16/16 - 5s - loss: 0.5574 - accuracy: 0.7402 - 5s/epoch - 331ms/step
# Test Accuracy: 0.7401574850082397

# %%
# Optionally, save the model for future use
# model.save_pretrained('/content/drive/My Drive/bert_model')

# %%
import numpy as np
from sklearn.metrics import classification_report

# Make predictions
predictions = model.predict(test_dataset.batch(16))
predicted_labels = np.argmax(predictions.logits, axis=1)

# Generate classification report
print(classification_report(test_labels, predicted_labels))
# Out:
# 8/8 [==============================] - 8s 641ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        33
#            1       0.74      1.00      0.85        94
#
#     accuracy                           0.74       127
#    macro avg       0.37      0.50      0.43       127
# weighted avg       0.55      0.74      0.63       127

# %%
topic_model = BERTopic(language="english")
topics, probabilities = topic_model.fit_transform(grouped_reviews['text'])
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
topic_freq = topic_model.get_topic_info()
top_5_topics = topic_freq.head(6)  # Includes the -1 topic which is for outliers

for topic in top_5_topics['Topic'][1:]:  # Excluding -1 if present
    print(f"Topic {topic} Overview:")
    print("Words and Weights:", topic_model.get_topic(topic))
    print("Representative Document:", topic_model.get_representative_docs(topic))
    print("\n")
# Out:
# Topic 0 Overview:
# Words and Weights: [('taco', 0.05308446328229343), ('salsa', 0.03187793789097344), ('food', 0.03147385713370956), ('mexican', 0.027112915205173907), ('burrito', 0.025667169087116647), ('place', 0.024100052392378335), ('good', 0.02275853800884453), ('great', 0.01969361374967897), ('one', 0.016079618486939503), ('get', 0.015935989038223446)]
# Representative Document: ['amazing amazing taco loaded brim freshest ingredient let honest real reason im excited found placethe salsa bar wow many amazing complimentary salsa choose felt like heaven think favorite pistachio soo unique generousi wouldnt expect place give much free especially place upscale santa barbara great service totally recommend place others area wonderful price much hole wall would never found place yelp glad mango salsa amazing taco true santa barbara gem family run spot deserves praise definitely worth line get hand food importantly salsa pretty much cant go wrong highly recommend ordering taco first time experience diversity deliciousness monys offer go tos al pastor pollo en mole carnitas chip freshly fried perfect mean dive salsa mentioned show stopper avocado creamy perfection peanut salsa salty spice love pistachio salsa unique simply world see one dancing front throwing back shot salsa thats im embarrassed damn good local know popular spot get longer wait fulfill taco need truth joint town deserving loving following place hand best taco spot sb best taco ive outside mexico city ive yet eat something didnt love carnitas chorizo definite gotos great price quick service dont let length line scare salsa bar bomb indulge pistachio avocado salsa youll never satisfied another salsa la super rica there line give huge salsa bar chip refill taco pretty tasty recommend al pastor yum husband town visiting day way coast hermosa beach stopped monys based yelp review saw honesty say carnitas burrito one best ever husband got assortment taco barbacoa carnitas another pork agreed authentic great taco salsa bar great addition grab salsa meal favorite pistachio im looking forward getting back santa barbara come back monys hype reeeeal people staunch taco lover everyone sb raf monys detests early closing time timing thing right brought parent second taco tasting spot right closing asada adobado pescado barbacoa taco come classic cilantro onion topping pescado ceviche topping indeed delicious especially beautiful salsa bar everyone praised loved avocado pistachio salsa particular extra point free chip outdoor seating really cute website ill definitely back try meat drink salsa straight bar straw clean inviting friendly staff great taco awesome salsa bar including avocado salsa mango salsa definitely come back next trip freakin good hurt among wide variety meat includes specialty like barbacoa lingua created salsa one pistachio salsa missed really good comfort food quaint place love place came summer vacation food great doesnt take long either salsa amazing amazing taco super delicious avocado salsa living los angeles fair share good mexican food monys definitely rank list go tos come taco lengua tripa favs location great service friendly con would early closing hour good friendly fresh busy accommodating im writing remember visit place next time im area yummy salsa bar meat tasty dont skimp amount meat taco either editing let everyone know parking suck dont expect seat inside small space would willing bet everything menu amazing taco generally got adobaba pollo en mole pescado incredible hit perfect spot wanted delicious easy lunch family fresh authentic fabulous huge burrito bring appetite taco super reasonably priced need buy several young boy ate two much seating maybe plan take vacation preferred seating got lucky able eat outside restaurant food good wow wow wow must agree review place really good mexican food decent price visiting santa barbara day looked mexican food first choice glad decided try got steak fajitas pollo asado hard shell tac fajitas awesome flavor decent portion hard shell taco seem fresh topped fresh lettuce cheese taco food well friend got steak plate decent size steak grilled onion plate came rice bean tortilla salsa selection big course tried fav avocado green salsa overall place amazing would definitely back visit santa barbara oh man soooooooo good said like five time eating carnitas burr ...
#
#
# Topic 1 Overview:
# Words and Weights: [('bowl', 0.031315302106876615), ('ramen', 0.02967151649632369), ('food', 0.029258254565647845), ('noodle', 0.027214879816444167), ('place', 0.026191512639439744), ('good', 0.02372244750736476), ('thai', 0.020828037559523876), ('rice', 0.018066172340120812), ('spicy', 0.017849202604052528), ('soup', 0.01733418125073179)]
# Representative Document: ['great flavored food good service spring roll awesome seen review stating food greasy cooked perfectly fresh tasting good tom ka gai curry dish food overall pretty good like come thai fix pretty good consistent walk house mood thai definitely satisfies love green curry restaurant clean service always great one best thai spot santa barbara particular restaurant nice atmosphere quite comfortable food well prepared delicious nice ingredient flavor serving moderate however pad thai smallest serving size ever received thai restaurant country thailand sequencing timing food coming kitchen poor totally confused entirely syncopated mentioned server didnt seem make difference fault likely lie management kitchen staff doesnt seem prescribed plan sequence food service ordered food six several salade pad thai several curie spicy eggplant first item arrive table pad thai perhaps minute later followed curry another minute salad another minute eggplant food mentioned great service average poor atmosphere nice tricky one rate got delivery spring roll pad thai chicken cashew without doubt best delivery thai ive ever gotten pad thai perfect ratio plenty flavor eaten five time always found food one better thai restaurant last two time ive eaten food mediocre something changed need get back track pad thai alright however small portion wasnt worth price coming year loved food continued support business untill today family came lunch greeted nice waitress brought drink getting ready order appetizer owner walk say hey remember guy guy spilt soda last time made huge mess took u min clean guy going make mess need sit outside thought joking asked serious said ya continued say rude comment eventually decided walk yes might spilt soda little table last time helped clean accident obviously every time came lunch spent buck always tipped walked shock told loved food dont know wrong said fck unbelievable food good reasonably priced maybe enjoy lunch owner isnt around waitress super embarrassed kept apologizing behalf rude bos restaurant business isnt everyone based review ive read isnt first time he treated people disrespect good luck surprised restaurant bad review show hr closing place packed still table sit party two walk get greeted whatever thats biggie got skin fact said couldnt serve u crap asked said close said still got hour left walked away left standing embarrassed walked car watched see would treat people yet big party people show sure enough know took never eat one get treated like aint human year people wow service received owner beyond disrespectful feel bad seems like really dislike job perhaps u favor retire let staff handle job clearly mentally unstable see ya never disappointed used better eggplant cut huge chunk super hard sure still raw basically floating oil took back cooked eggplant soggy still pretty hard even difference smaller chunk coming walked surprised upscale decor obvious steady flow togo order going ive sat ordered go crab cheese rangoon fantastic starter love shrimp pad thai craving thai food give shot restaurant nice atmosphere good service food quite flavorful delicious los angeles didnt expect serve authentic delicious thai food santa barbara definitely go back favorite thai place town boba good favorite larb fresh roll beef broccoli spicy eggplant green curry pad thai pad prik king pad see ewe best thai restaurant santa barbara question asked mic drop review kidding cant leave hanging like quite seriously ive exploring thai food option county year menu fan never beat quality quantity flavoring meal variety blow place water option gf vegan eater almost always order take stuff face judged inhouse environment actually semiromantic table service experienced average little slower youre date spending time friend family noticeable actually quite enjoyable wait staff asking question every second method madness calling order pick sharing friend boyfriend splitting couple meal week portion big would recom ...
#
#
# Topic 2 Overview:
# Words and Weights: [('food', 0.02648274185421786), ('service', 0.02133403889061558), ('good', 0.020567128530483057), ('great', 0.018516632531570033), ('time', 0.018211330829378654), ('place', 0.017830043371899872), ('restaurant', 0.017828958414126246), ('back', 0.01556389689542895), ('get', 0.015135536091885369), ('order', 0.014613484460534369)]
# Representative Document: ['food really good love chickpea give seated time service really slow good news food worth wait even kid liked food thats always plus cool spot loved environment staff friendly unfortunately waitress wasnt helpful asked question didnt seem want give time day also felt rushing u done mostly bothered restaurant wasnt busy time food came though amazing would definitely come hope better waiter couldnt go negative star get one ordered chicken dish came uncooked clearly raw center kind squint wonder cooked pink shiny inside took back returned minute later cooked chicken plate side dish room temp chicken placed right back dish came meantime everyone else done dinner chicken dish partially eaten realize plate completely unacceptable food poisoning waiting happen avoid restaurant nothing else good dish could disregard obvious danger kitchen average food except actively bad stuff staff blandly niceish failed take problem seriously health inspector id taking closer look else going kitchen handling food properly wash hand certified correctly restaurant work plenty restaurant around dont put risk health stay away came dinner drink first night vacation beautiful space unfortunately service far decent service received man put chickpea table smile friendly hostess sat u ended sat nearly minute contact tried get server attention waiting table next u basically ignored u would make eye contact wish busy night could bit grace situation wasnt got finally let hostess know leaving let know said thank im second chance though might give another try future santa barbara visit menu looked great ordered cobb salad uber eats absolute worst salad ever tried eat bacon chicken taco strip old stale minus star thats would given place cute ordered recharged drink spicy actually delicious server suggested wanted something similar michelada server served u right away kept instantly getting drink refilled ordered fried calamari appetizer mmm delicious best freshest calamari ive ever mediocre around go convenient space comfortable food ok service inconsistent first time benchmark favored many restaurant outdoor seating area give gorgeous ambience perfect casual conversation even date night also wait staff friendly attentive informative menu pulled pork sweet tender though apparently much young ordering joked waitress fish chip crispy tasty much like find alley location pozole verde overspiced masked ingredient natural flavor honestly wish could give complimentary fried chick pea star would legitimately buy bag oh btw spelled banh mi wrong menu trust im viet acoustic landmark eatery place terrible couldnt wait get worse dropped dinner order lame apology minute enduring echoladen acoustic wouldnt split check others table happy hour price concession dropping order ala suspect join pantheon outofbusiness boardedup state street restaurant first time place let alone city great vibe awesome searing area tried hot wing next pulled pork sandwhich come check ut never always see busy night go try day service look like employee work like robot job dont come bd check get order give thet need go find get bill sad food star take time average time get restaurant like full food worm look good test bad meet tasty look like gray old get lattice rap go true rap usad much rap eat like salat pasta order pasta bolognese get pasta whit lite tomato sauce sprinkle meet see pic blow ready well dont see reason back sad foodsad customer sad business came beer complimentary fried chickpea good oh live music def recommend wife arrived early monday afternoon seated patio minute promptly greeted waiter seem think immediately ready place order attitude inconvenience asked minute read menu since first time asked water acknowledged walked back behind bar continue conversation coworkers clearly forgetting request minute returned cavalier attitude realized hed forgotten water ordered cocktail since tired waiting seem jog memory previous order water cocktail arrive shortly wife  ...
#
#
# Topic 3 Overview:
# Words and Weights: [('breakfast', 0.04208148310634673), ('egg', 0.025422822687233466), ('food', 0.02452401164964259), ('good', 0.022742770318911816), ('place', 0.022670831907408425), ('coffee', 0.02103237472193849), ('great', 0.019872791202646282), ('toast', 0.017893197235007534), ('service', 0.017645546472728726), ('delicious', 0.016011706113483775)]
# Representative Document: ['good breakfast sit restaurant offer wide range food worth money delicious family friendly sometimes wait time amazing tucked end shopping center kmart staff okay extra friendly im also girl midwest everyone friendly talkative food great portion plentiful ingredient fresh food decently good super filling ordered huevos rancheros much couldnt finish huge appetite say lot friend ordered top sirloin steak z fried chicken egg benedict came around wasnt super packed like expected got seat instantly addition food arrived together fast portion food filling everything worth price got fried chicken benedict everything perfect except biscuit bottom slightly cold chicken topping hot waitress assisted u seemed bit annoyed man seated u super polite overall im ever back area would likely go back super empty stomach excellent service yummy food awesome pricing stopped way back camping everyone welcoming always delicious good service two thumb special always interesting corn bread something never want end yummy good consistent breakfast food also mimosa new place goleta old pizza placecan get loud time easy find definitely must breakfast chilequiles apple chicken sausage egg impressed chilequiles incredible freshly made chip wonderful egg andouille sausage one best ive sausage egg also done well staff attentive friendly great way start day great place breakfast ordered crab cake benedict split enough food fresh available weekend holy shit say utmost satisfying way special menu chorizo benedict avocado grilled onion dish amazing flavor point salt needed pepper needed salsa hot sauce needed perfect must try took leap faith went brunch town shrimp andouille sausage grit point crab cake benedict egg rancher omelet also point value location cajun kitchen ideal stop breakfast laid back santa barbara coming chicago vacation expected greek style breakfast house got expected best dont expect four star restaurant cozy seat atmosphere gumbo wasnt real cajun even louisiana offer generous portion decent price entire one tip hearty breakfast person get either homemade muffin one side delicious meh im sure four star bland mexicajun came alumnus weekend min wait stand doorthey call name whisper chili verde pork home fry tortilla pork dry tasty home fry tasted like toasted boiled potato tortilla bland dry well coffee old bitterand really dont like lady way either gf fried chicken waffle chicken batter bland chicken moist waffle exception entire breakfastvery tasty get waffle oh try beignet nola nice snack food came get busy thing may rushedbut zero reason come back recommend given place choose area came saturday short wait ordered beignet hash brown egg jambalaya waffle everything amazing server friendly food came fast would definitely come recommend friend great breakfast spot crowded sunday morning able sit counter immediately ordered rancher omelette see attached pic menu description ordered crispy hash brown w sourdough toast omelette stuffed lot bacon topped delicious avocado coffee good hot service excellent definitely back im area wonderful food service chile verde omelet chunk pork simmered veggie green sauce jack cheese sour cream couldnt better came best hash brown ever also coffee wasnt good coffee overall definitely eat area bacon rock egg rubber cheese softer rubber tasted slightly burnt hashbrowns undercooked water tasted kind like sewage recommend really good place found though yelp review didnt disappoint wish little bigger there nothing food great loved every bite stopped breakfast pretty busy service great food okay wasnt impressed quality thought pricing wise expensive quality food wouldnt come back would probably try find another place first couple month ago went boyfriend looking quick breakfast went zoo boyfriend greeted walked waiter stopped check okay service amazing food amazing ordered pancake egg benedict omelette rancher omelette best omelette ive pancake soso egg benedict tasted alright also worth money h ...
#
#
# Topic 4 Overview:
# Words and Weights: [('pizza', 0.16509596474031282), ('crust', 0.03418021672809285), ('place', 0.025944474232318295), ('topping', 0.02103211514211242), ('great', 0.02050660359383914), ('slice', 0.019900687813005684), ('order', 0.019551733310863233), ('time', 0.01930929548828799), ('good', 0.01873643171331268), ('service', 0.018360420551087924)]
# Representative Document: ['let start thick crust fan yes already slgihtly dont like kind pizza however super delicious tomato sauce seemed super fresh would cool could jar consistency someitmes burned enough cheese much blah blah need worked friend came two day row yesterday felt like customer service amazing came around pm wednesday worker serving u positive attitude tried see name tag give credit clout manager could possibly see review maybe give raise bonus whatever wasnt wearing one remember glass blaze worker wherever hope good day disappointed experience ordered three pizza requested highrise crust paid filling drink called u said forgot charge u highrise crust price told deleted whole transaction needed rerun card additional charge time pizza oven brought u two three extremely well doneburnt three pizza extremely thin crust im even sure got highrise request none sliced really hard time trying eat unfortunately tasted burnt went asked new pizza replace burnt pizza told u would give u one new pizza since half burnt pizza looked really burnt new pizza meant replace burnt pizza also looked burnt didnt taste better first pizza hour parking meter couldnt wait another pizza cooked point none u wanted eat gross pizza anywaysthis first visit blaze pizza usually visit pieology mod pizza dont think going back lack customer service food wasnt good waste really enjoy passionfruit juice ordered online picked store returned hotel eat pizza burned bottom disappointing umm world first experience asked bbq pizza get little squirter little squirt circle mostly dough showing add cheese add couple spoon full go outside wait wait wait finally come back check baker busy making box doesnt look minute say pizza f place wow place got going service moment walked put personal personal pizza prompt service fast wood fired pizza crispy delish woodstock take lesson crew return blaze next time looking tasty meal iv really disappointed last visit usually love blaze went half hour ago started eating pizza find undercooked understand guy busy right people coming back school seriously crust still doughy super super disappointed blaze best pizza always go one topping get pineapple sooo many choice love create pizza reason dont give ive gone time something wanted lack inventory place dank also try new garlic dough knot fire honestly food really good bad experience busy day waiting line tell wanted stoped started clean willing wait understandable five minute go theyre starting refill food item understandable another five minute go theyre still cleaning sitting around look like theyre little meeting near cash register line literally people waiting getting longer min another five minute go employee getting drink dispenser still standing around cash register back lax meeting total b waisted min standing one employee told anyone going stoped take break pm busiest point needle say went go get cosco pizza even saw people blaze getting pizza costco blaze always great pick topping want pizza isla vista location well staffed fullsize retail location always great able order gf crust vegan cheese called state street location pm last night placed order pizza told would take minute could see amount reflected pending credit card order definitely came showed minute later pm told worker register didnt know talking reluctantly asked worker front line writes name paper told pizza hadnt made yet asked wait another minute said unhappy worker register shrugged shoulder said didnt care said manager needlessly say walked seriously bad service ive many blaze location state street location first opened excited loyal customer service always fast friendly lately weve noticed disappointing decline customer service past two time weve including tonight service painfully slow employee looked miserable didnt even acknowledge u upon arriving said hello barely got hi back left thanked girl boxing pizza didnt even respond even look direction pizza always great seems employee need morale boost ...

# %%
topic_model.visualize_barchart(top_n_topics=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="559f825b-6c3c-45d7-a9a1-465fb8375074" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("559f825b-6c3c-45d7-a9a1-465fb8375074")) {                    Plotly.newPlot(                        "559f825b-6c3c-45d7-a9a1-465fb8375074",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.025667169087116647,0.027112915205173907,0.03147385713370956,0.03187793789097344,0.05308446328229343],"y":["burrito  ","mexican  ","food  ","salsa  ","taco  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.026191512639439744,0.027214879816444167,0.029258254565647845,0.02967151649632369,0.031315302106876615],"y":["place  ","noodle  ","food  ","ramen  ","bowl  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.018211330829378654,0.018516632531570033,0.020567128530483057,0.02133403889061558,0.02648274185421786],"y":["time  ","great  ","good  ","service  ","food  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.022670831907408425,0.022742770318911816,0.02452401164964259,0.025422822687233466,0.04208148310634673],"y":["place  ","good  ","food  ","egg  ","breakfast  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.02050660359383914,0.02103211514211242,0.025944474232318295,0.03418021672809285,0.16509596474031282],"y":["great  ","topping  ","place  ","crust  ","pizza  "],"type":"bar","xaxis":"x5","yaxis":"y5"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2478026b-27d7-4c8c-b801-7e50e729fcce" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2478026b-27d7-4c8c-b801-7e50e729fcce")) {                    Plotly.newPlot(                        "2478026b-27d7-4c8c-b801-7e50e729fcce",                        [{"customdata":[[0,"taco | salsa | food | mexican | burrito",87],[1,"bowl | ramen | food | noodle | place",54],[2,"food | service | good | great | time",41],[3,"breakfast | egg | food | good | place",39],[4,"pizza | crust | place | topping | great",26],[5,"beer | great | food | good | burger",23],[6,"food | great | good | place | service",20],[7,"sandwich | pickle | place | salad | great",19],[8,"food | great | fish | good | clam",19],[9,"food | great | service | dish | restaurant",18],[10,"food | chicken | salad | katsu | place",17],[11,"sushi | roll | place | good | salmon",16],[12,"italian | pasta | pizza | food | service",14],[13,"coffee | cat | tea | starbucks | place",13],[14,"burger | fry | place | good | food",12]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[87,54,41,39,26,23,20,19,19,18,17,16,14,13,12],"sizemode":"area","sizeref":0.054375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[10.546951293945312,11.515809059143066,10.130790710449219,10.533246040344238,7.047362327575684,8.430545806884766,8.93843936920166,10.407514572143555,10.757864952087402,8.906149864196777,9.806280136108398,11.798704147338867,7.161032676696777,10.820890426635742,9.744773864746094],"xaxis":"x","y":[0.8517786264419556,1.256077766418457,1.3964815139770508,-0.6224467158317566,11.158207893371582,1.753808617591858,2.292823076248169,-0.0538482703268528,0.5194897055625916,1.9295083284378052,0.3552469313144684,1.567626714706421,11.044624328613281,-0.7695146799087524,0.89653080701828],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5d ...

# %% [markdown]
# **Topic modeling for closed restuarants reviews**

# %%
closed_restaurants_reviews = grouped_data[grouped_data['is_open']== 0]['text']

topic_model = BERTopic(language="english")
topic_model.calculate_probabilities = True
topics, probabilities = topic_model.fit_transform(closed_restaurants_reviews)

topic_freq = topic_model.get_topic_info()
top_5_topics = topic_freq.head(6)  # Includes the -1 topic which is for outliers

for topic in top_5_topics['Topic'][1:]:  # Excluding -1 if present
    print(f"Topic {topic} Overview:")
    print("Words and Weights:", topic_model.get_topic(topic))
    print("Representative Document:", topic_model.get_representative_docs(topic))
    print("\n")


topic_model.visualize_barchart(top_n_topics=5)
# Out:
# Topic 0 Overview:
# Words and Weights: [('food', 0.05322277601516285), ('place', 0.04013378422408705), ('good', 0.038489046095754466), ('great', 0.03326437217830497), ('service', 0.02980050495091607), ('time', 0.02550333590536123), ('restaurant', 0.024654759988586763), ('back', 0.024144124420986582), ('one', 0.02392821106955637), ('like', 0.02384763353853834)]
# Representative Document: ['yummmmmmmm boyfriend checked place whim smelled good walked got simple stuff even tho menu expansive phenomenal theyve homemade salad dressing bought bottle homemade daily soup waitress pam ray sunshine made whole experience much better plus place beautiful inside reasonably priced id definitely recommend wonderful food terrible customer service lied asked seated towards back said space sat u door cold went looked back room enough room back silverware gross waitress rude laura back game meal excellent service excellent great garlic bread well back often like location decor cute date food decent nothing special came celebrate friend birthday excellent lunch special mixed green salad house dressing tasty opted variety mix ravioli nice eat meat dont cheese often able accommodate gave mix mushroom butternut squash good server super nice ill call get name hope back santa barbar near future dine husband spent week santa barbara year ago hadnt planned eat italian since good la pascuccis many raf lady wine country bus tour decided try ravioli sampler one lady recommended exquisite baked salmon pasta dish cream sauce also delight cheese bread addictive premise pascuccis fancier expected indoor outdoor seating food cost seemed fair especially state street area good bargain la standard anyway menu large lot cheesy creamy offering feature many unusual fish seafood dish generally dont care much service food good dont recall anything stood one way wait staff pascuccis cool place go santa barbara nice change pace nice price robustly romantic honeymoon anniversary date value variety would keep u coming back italian place doesnt make fresh pasta little disappointing good salad service wonderful bread little run greatly needed tender loving care nice place okay atmosphere cant give one star would fair patron read post try italian restaurant leave comment see thought would love know thought ordered takeout stay santa barbara found difficult place phone order due language barrier bread tough lasagna runny also dessert cheese cake gritty sorry say wont back absolute worst meal ive long time obviously costco salad costco ravioli cold blob sauce food hot really bad chicken alfredo tasted like chalk cold cooked well unpleasant dinner cheap price waitress lovely kind think aware couldnt eat meal left provide dessert go u nice paid review spot excellent italian food welcoming entry awesome small half table facing fireplace bad taken entry wrap around another room lot table booth owner manager nice older gal friendly food awesome price reasonable right middle action state street garlic bread topped spice oil baked come table bowl good good wine beer selection pasta best part house dish called pasta pascucci shrimp chicken caramelized onion pepper creme sauce sound heavy wasnt filling especially garlic bread ate wife sun dried tomato shrimp bed spinach linguini son kid meal bolognese liked adult meal added wine peronis lemonade son bill service also good bus boy helping waitress back sure fact im sure wife eating left over write morning wife love love love santa barbara goto destination need getawaywhether day weekend anyone know santa barbara tell youthere place eat american riviera truly foodie paradise hell theyve even dedicated month month october sb eating scene call epicure sb finding great food decent price point santa barbara always challenge partif want great food town often going pay pretty penny experience pascucci however wonderful exception rule quickly become one fave place eat admit wanted yelp place year ago wanted make sure experience consistent read many review including notsonice one little iffy ive waited wed eaten time reviewing discovered place wife birthday got pick wanted eat craving italian food remembered little place near paseo nuevo cute name pascucci seemed cute name went first thing notice step delicious aroma fresh baked bread garlic mmmmmmmmmm made mouth water waiting table restaurant something c ...
#
#
# Topic 1 Overview:
# Words and Weights: [('pizza', 0.18349075555479635), ('order', 0.041139137422833705), ('service', 0.03630900728627576), ('place', 0.03531970805582818), ('time', 0.03492448558639773), ('sandwich', 0.03484092483756664), ('customer', 0.034241808471205275), ('like', 0.031402312345159326), ('crust', 0.03041172369174739), ('back', 0.028413778470878056)]
# Representative Document: ['going rethink stopping several pieology location always great service great meal still got great meal customer service need refresh change wasnt greeted hello blank starethe hello gave met blankannoyed gaze want salad pizza rest process went planned ordered drink went fill cup there icei let manager im assuming know reply yep working today thats nothing else head handed cup would nice note machine might saved botheredclearly repeat wasnt one say something tell another customer would refund money didnt want extra liquid cup love pieologywell hold travel south another visit amazing price point great quality ingredient love crust option wheat gluten free cauliflower like grow current trend great place aquick biteselect pizza topping brick oven pizza le min great tasting crust nice selection topping sauce cheese pieology least one least favorite personal size pizza joint would recommend place blaze isla vista definitely worth short drive better yet willing spend little rustys pizza parlor favorite pizza joint goleta great pizza perfect crust taylor made suggestion sauce solved dilemma topping fun plentiful good quality price big fan thin crust pizza one reason like pieology like idea able customize pizza think dont large selection choose pepperoni slice small shrunken baking server kind helpful place awesome easy find great service quick line pizza amazing highly recommend update gave place rest tried several time since place convenient home improved service product even introducing thick crust im revising rating upwards old review pulled pm last friday thought closed light signage turned several chair put dining room hour posted door indicated open pm taken hint upon entering greeted impatient surly crew broken line trying hardest clean put everything away night ordered three regular menu pizza offering customization nothing fancy standard pizza straight menu go alfredos alfredo told started building would basil mushroom ingredient guess missing stuff veggie substitution choice limited ingredient unappetizing mess scattered around lifted refrigeration asked put pesto sauce alfredos baking wait long realized three six pizza sitting probably sat getting cold one worker folded empty pizza box right next pizza let guess folding box task sidework checklist night right prep pizza box crew open next morning meanwhile guy let bunch pizza sit getting fanned cooled waving cardboard boxed alfredos without pesto sauce tried pas insisted put already missing mark badly turn pesto line grudgingly went back located probably found right next saturday preprepped mushroom fresh basil two three pizza blackened around edge burnt underneath pizza cold cheese congealed gone elsewhere management retraining hubby stopped one nearby food place already closed pieology still open used pieology near work enjoyed quite lot closed im sure always busy anyway one wasnt busy right holiday thats probably employee helped u professional polite store large number updated option modern healthconscious crowd including cauliflower crust husband got tried bite liked pizza made exactly ordered ingredient fresh tasty service fast happy see new stuff like deep dish crust salad reason thought one miracle soda machine dispensed flavor could imagine standardold fashioned soda fountain slight disappointment functional fresh id stop convenient parking clean store fresh food dont know anybody dislike place reasonable price tasty crust wide range topping limitation want pizzeria favorite pizza far place dirty got youd expect place clean start time customer restroom trash hadnt taken table top crumb everywhere floor dirty empty napkin dispenser drink dispenser looked splattered drink residue thanks great pizza obviously closing crew didnt job great service great food line bit long sometimes understandable since ive witnessed people add every single topping inherently make process slower eat least week typical build pizza place much different write ton par ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5e193c7c-92ab-4e93-a731-30dd015403d8" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e193c7c-92ab-4e93-a731-30dd015403d8")) {                    Plotly.newPlot(                        "5e193c7c-92ab-4e93-a731-30dd015403d8",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.02980050495091607,0.03326437217830497,0.038489046095754466,0.04013378422408705,0.05322277601516285],"y":["service  ","great  ","good  ","place  ","food  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.03492448558639773,0.03531970805582818,0.03630900728627576,0.041139137422833705,0.18349075555479635],"y":["time  ","place  ","service  ","order  ","pizza  "],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks ...

# %%
topic_model.visualize_hierarchy(top_n_topics=6)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8154c4ec-05e5-4c8b-a22c-527eb1e79356" class="plotly-graph-div" style="height:230px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8154c4ec-05e5-4c8b-a22c-527eb1e79356")) {                    Plotly.newPlot(                        "8154c4ec-05e5-4c8b-a22c-527eb1e79356",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.38715985158181143,0.38715985158181143,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":230,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["0_food_place_good","1_pizza_order_service"],"tickvals":[-5.0,-15.0],"type":"linear","zeroline":false,"range":[-20.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marke ...

# %%
print(topic_model.calculate_probabilities)
topic_model.calculate_probabilities = True
# Out:
# True

# %%
topic_model.visualize_distribution(probabilities[1],0.0002) #min_probability=0.0002
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="530dd8e7-08fa-4ca3-a517-afbe6ff02c4b" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("530dd8e7-08fa-4ca3-a517-afbe6ff02c4b")) {                    Plotly.newPlot(                        "530dd8e7-08fa-4ca3-a517-afbe6ff02c4b",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.2108884919642473,0.4517734656358239],"y":["\u003cb\u003eTopic 0\u003c\u002fb\u003e: food_place_good_great_se...","\u003cb\u003eTopic 1\u003c\u002fb\u003e: pizza_order_service_plac..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type ...

# %% [markdown]
# **topic modeling for Open restuarants reviews**

# %%
open_restaurants_reviews = grouped_data[grouped_data['is_open']== 0]['text']

topic_model = BERTopic(language="english")
topic_model.calculate_probabilities = True
topics, probabilities = topic_model.fit_transform(open_restaurants_reviews)

topic_freq = topic_model.get_topic_info()
top_5_topics = topic_freq.head(6)  # Includes the -1 topic which is for outliers

for topic in top_5_topics['Topic'][1:]:  # Excluding -1 if present
    print(f"Topic {topic} Overview:")
    print("Words and Weights:", topic_model.get_topic(topic))
    print("Representative Document:", topic_model.get_representative_docs(topic))
    print("\n")


topic_model.visualize_barchart(top_n_topics=5)
# Out:
# Topic 0 Overview:
# Words and Weights: [('food', 0.052032687405809575), ('place', 0.04025956829347184), ('good', 0.03826316503467018), ('great', 0.033372005546988895), ('service', 0.02999981921508981), ('time', 0.025481322725764945), ('restaurant', 0.024666939632407164), ('like', 0.024292877567783835), ('back', 0.024051285052350598), ('one', 0.023510312627112215)]
# Representative Document: ['yummmmmmmm boyfriend checked place whim smelled good walked got simple stuff even tho menu expansive phenomenal theyve homemade salad dressing bought bottle homemade daily soup waitress pam ray sunshine made whole experience much better plus place beautiful inside reasonably priced id definitely recommend wonderful food terrible customer service lied asked seated towards back said space sat u door cold went looked back room enough room back silverware gross waitress rude laura back game meal excellent service excellent great garlic bread well back often like location decor cute date food decent nothing special came celebrate friend birthday excellent lunch special mixed green salad house dressing tasty opted variety mix ravioli nice eat meat dont cheese often able accommodate gave mix mushroom butternut squash good server super nice ill call get name hope back santa barbar near future dine husband spent week santa barbara year ago hadnt planned eat italian since good la pascuccis many raf lady wine country bus tour decided try ravioli sampler one lady recommended exquisite baked salmon pasta dish cream sauce also delight cheese bread addictive premise pascuccis fancier expected indoor outdoor seating food cost seemed fair especially state street area good bargain la standard anyway menu large lot cheesy creamy offering feature many unusual fish seafood dish generally dont care much service food good dont recall anything stood one way wait staff pascuccis cool place go santa barbara nice change pace nice price robustly romantic honeymoon anniversary date value variety would keep u coming back italian place doesnt make fresh pasta little disappointing good salad service wonderful bread little run greatly needed tender loving care nice place okay atmosphere cant give one star would fair patron read post try italian restaurant leave comment see thought would love know thought ordered takeout stay santa barbara found difficult place phone order due language barrier bread tough lasagna runny also dessert cheese cake gritty sorry say wont back absolute worst meal ive long time obviously costco salad costco ravioli cold blob sauce food hot really bad chicken alfredo tasted like chalk cold cooked well unpleasant dinner cheap price waitress lovely kind think aware couldnt eat meal left provide dessert go u nice paid review spot excellent italian food welcoming entry awesome small half table facing fireplace bad taken entry wrap around another room lot table booth owner manager nice older gal friendly food awesome price reasonable right middle action state street garlic bread topped spice oil baked come table bowl good good wine beer selection pasta best part house dish called pasta pascucci shrimp chicken caramelized onion pepper creme sauce sound heavy wasnt filling especially garlic bread ate wife sun dried tomato shrimp bed spinach linguini son kid meal bolognese liked adult meal added wine peronis lemonade son bill service also good bus boy helping waitress back sure fact im sure wife eating left over write morning wife love love love santa barbara goto destination need getawaywhether day weekend anyone know santa barbara tell youthere place eat american riviera truly foodie paradise hell theyve even dedicated month month october sb eating scene call epicure sb finding great food decent price point santa barbara always challenge partif want great food town often going pay pretty penny experience pascucci however wonderful exception rule quickly become one fave place eat admit wanted yelp place year ago wanted make sure experience consistent read many review including notsonice one little iffy ive waited wed eaten time reviewing discovered place wife birthday got pick wanted eat craving italian food remembered little place near paseo nuevo cute name pascucci seemed cute name went first thing notice step delicious aroma fresh baked bread garlic mmmmmmmmmm made mouth water waiting table restaurant something c ...
#
#
# Topic 1 Overview:
# Words and Weights: [('pizza', 0.1593283424577311), ('sandwich', 0.04012683442145772), ('order', 0.03936709005748742), ('time', 0.0353955533875135), ('service', 0.03519055786840517), ('place', 0.03317582519652147), ('like', 0.033106369833015736), ('customer', 0.03242445304503846), ('back', 0.02814133722391484), ('good', 0.027332955775404583)]
# Representative Document: ['going rethink stopping several pieology location always great service great meal still got great meal customer service need refresh change wasnt greeted hello blank starethe hello gave met blankannoyed gaze want salad pizza rest process went planned ordered drink went fill cup there icei let manager im assuming know reply yep working today thats nothing else head handed cup would nice note machine might saved botheredclearly repeat wasnt one say something tell another customer would refund money didnt want extra liquid cup love pieologywell hold travel south another visit amazing price point great quality ingredient love crust option wheat gluten free cauliflower like grow current trend great place aquick biteselect pizza topping brick oven pizza le min great tasting crust nice selection topping sauce cheese pieology least one least favorite personal size pizza joint would recommend place blaze isla vista definitely worth short drive better yet willing spend little rustys pizza parlor favorite pizza joint goleta great pizza perfect crust taylor made suggestion sauce solved dilemma topping fun plentiful good quality price big fan thin crust pizza one reason like pieology like idea able customize pizza think dont large selection choose pepperoni slice small shrunken baking server kind helpful place awesome easy find great service quick line pizza amazing highly recommend update gave place rest tried several time since place convenient home improved service product even introducing thick crust im revising rating upwards old review pulled pm last friday thought closed light signage turned several chair put dining room hour posted door indicated open pm taken hint upon entering greeted impatient surly crew broken line trying hardest clean put everything away night ordered three regular menu pizza offering customization nothing fancy standard pizza straight menu go alfredos alfredo told started building would basil mushroom ingredient guess missing stuff veggie substitution choice limited ingredient unappetizing mess scattered around lifted refrigeration asked put pesto sauce alfredos baking wait long realized three six pizza sitting probably sat getting cold one worker folded empty pizza box right next pizza let guess folding box task sidework checklist night right prep pizza box crew open next morning meanwhile guy let bunch pizza sit getting fanned cooled waving cardboard boxed alfredos without pesto sauce tried pas insisted put already missing mark badly turn pesto line grudgingly went back located probably found right next saturday preprepped mushroom fresh basil two three pizza blackened around edge burnt underneath pizza cold cheese congealed gone elsewhere management retraining hubby stopped one nearby food place already closed pieology still open used pieology near work enjoyed quite lot closed im sure always busy anyway one wasnt busy right holiday thats probably employee helped u professional polite store large number updated option modern healthconscious crowd including cauliflower crust husband got tried bite liked pizza made exactly ordered ingredient fresh tasty service fast happy see new stuff like deep dish crust salad reason thought one miracle soda machine dispensed flavor could imagine standardold fashioned soda fountain slight disappointment functional fresh id stop convenient parking clean store fresh food dont know anybody dislike place reasonable price tasty crust wide range topping limitation want pizzeria favorite pizza far place dirty got youd expect place clean start time customer restroom trash hadnt taken table top crumb everywhere floor dirty empty napkin dispenser drink dispenser looked splattered drink residue thanks great pizza obviously closing crew didnt job great service great food line bit long sometimes understandable since ive witnessed people add every single topping inherently make process slower eat least week typical build pizza place much different write ton par ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ef9ec494-2584-4e2a-ad86-e11522f59458" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef9ec494-2584-4e2a-ad86-e11522f59458")) {                    Plotly.newPlot(                        "ef9ec494-2584-4e2a-ad86-e11522f59458",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.02999981921508981,0.033372005546988895,0.03826316503467018,0.04025956829347184,0.052032687405809575],"y":["service  ","great  ","good  ","place  ","food  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.03519055786840517,0.0353955533875135,0.03936709005748742,0.04012683442145772,0.1593283424577311],"y":["service  ","time  ","order  ","sandwich  ","pizza  "],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"tick ...

# %%
topic_model.visualize_hierarchy(top_n_topics=6)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="06083690-2257-49a1-b08c-8b2bedf480b8" class="plotly-graph-div" style="height:230px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06083690-2257-49a1-b08c-8b2bedf480b8")) {                    Plotly.newPlot(                        "06083690-2257-49a1-b08c-8b2bedf480b8",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.34284533332479616,0.34284533332479616,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":230,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["0_food_place_good","1_pizza_sandwich_order"],"tickvals":[-5.0,-15.0],"type":"linear","zeroline":false,"range":[-20.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"mark ...

# %%
topic_model.visualize_distribution(probabilities[1],0.0002) #min_probability=0.0002
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="168e1a5f-fd48-4185-9b89-78be9ab72ded" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("168e1a5f-fd48-4185-9b89-78be9ab72ded")) {                    Plotly.newPlot(                        "168e1a5f-fd48-4185-9b89-78be9ab72ded",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.2813095141146186,0.48989478668829467],"y":["\u003cb\u003eTopic 0\u003c\u002fb\u003e: food_place_good_great_se...","\u003cb\u003eTopic 1\u003c\u002fb\u003e: pizza_sandwich_order_tim..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"typ ...
